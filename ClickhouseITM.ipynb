# %% [markdown]
# <a href="https://colab.research.google.com/github/ekaratnida/Data-Engineer/blob/main/ClickhouseITM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install clickhouse-connect
# Out:
# Collecting clickhouse-connect
#   Downloading clickhouse_connect-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from clickhouse-connect) (2026.5.20)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.12/dist-packages (from clickhouse-connect) (2.5.0)
# Requirement already satisfied: zstandard in /usr/local/lib/python3.12/dist-packages (from clickhouse-connect) (0.25.0)
# Collecting lz4 (from clickhouse-connect)
#   Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading clickhouse_connect-1.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 19.8 MB/s eta 0:00:00
# Downloading lz4-4.4.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.6 MB/s eta 0:00:00
# Installing collected packages: lz4, clickhouse-connect
# Successfully installed clickhouse-connect-1.3.0 lz4-4.4.5

# %%
import clickhouse_connect

if __name__ == '__main__':
    client = clickhouse_connect.get_client(
        host='wel21t6m5g.ap-southeast-1.aws.clickhouse.cloud',
        user='default',
        password='',
        secure=True
    )
    print("Result:", client.query("SELECT 1").result_set[0][0])
# Out:
# Result: 1

# %%
result = client.query("SELECT * FROM helloworld.my_first_table")

# %%
result.result_columns[0:2]
# Out:
# [[107, 101, 101, 101, 102, 102, 102, 103, 107],
#  ['ITM',
#   'It is comma-separated',
#   'Hello, ClickHouse!',
#   'Granules are the smallest chunks of data read',
#   'This is data in a file',
#   'Insert a lot of rows per batch',
#   'Sort your data based on your commonly-used queries',
#   'Use FORMAT to specify the format',
#   'ITM']]
